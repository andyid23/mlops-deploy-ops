# %% [markdown]
# # Proyek Pengembangan Machine Learning Pipeline
# **Nama:** [Nama Anda]
# **Username Dicoding:** andyid
# **Tanggal:** 8 Juli 2026
#
# ## 1. Informasi Dataset
# - **Nama Dataset:** [Nama dataset Anda, misal: Heart Disease Dataset]
# - **Sumber:** [Link dataset, misal: UCI Machine Learning Repository]
# - **Jumlah Data:** [Jumlah baris] baris dan [Jumlah kolom] kolom
# - **Fitur:** [Sebutkan fitur-fitur utama]
# - **Target:** [Sebutkan target/label]
#
# ## 2. Permasalahan yang Ingin Diselesaikan
# [Jelaskan masalah bisnis atau masalah yang ingin diselesaikan dengan ML. Contoh: "Memprediksi apakah seorang pasien memiliki penyakit jantung berdasarkan fitur-fitur medis."]
#
# ## 3. Solusi Machine Learning & Target
# - **Solusi:** Membangun model klasifikasi/regresi menggunakan TensorFlow dan TFX pipeline.
# - **Target:** Mencapai akurasi minimal [X]% dengan metrik evaluasi [Accuracy/F1-Score/AUC].

# %%
import os
import sys
import tensorflow as tf
import tfx

print(f"TensorFlow Version: {tf.__version__}")
print(f"TFX Version: {tfx.__version__}")
# Out:
# TensorFlow Version: 2.10.1
# TFX Version: 1.11.0

# %%
# Jalankan langsung file local_pipeline.py
print("🚀 Memulai eksekusi pipeline TFX dengan Apache Beam...")
# %run andyid-pipeline/local_pipeline.py
print("✅ Pipeline berhasil dijalankan!")
# Out:
# 🚀 Memulai eksekusi pipeline TFX dengan Apache Beam...
# INFO:absl:Excluding no splits because exclude_splits is not set.
# INFO:absl:Excluding no splits because exclude_splits is not set.
# INFO:absl:Excluding no splits because exclude_splits is not set.
# INFO:absl:Generating ephemeral wheel package for 'C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\modules\\transform.py' (including modules: ['components', 'trainer', 'transform']).
# INFO:absl:User module package has hash fingerprint version ada18bfeef376af7db2592bb8e75cc8d9bffe7a95b02a9bb8e811ddd10f8d83c.
# INFO:absl:Executing: ['C:\\Users\\Dragon\\AppData\\Local\\Programs\\Python\\Python39\\python.exe', 'C:\\Users\\Dragon\\AppData\\Local\\Temp\\tmp52km_znx\\_tfx_generated_setup.py', 'bdist_wheel', '--bdist-dir', 'C:\\Users\\Dragon\\AppData\\Local\\Temp\\tmph7qazq7u', '--dist-dir', 'C:\\Users\\Dragon\\AppData\\Local\\Temp\\tmpqtvxrbo2']
# Menjalankan pipeline: andyid_pipeline
# INFO:absl:Successfully built user code wheel distribution at 'C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\_wheels\\tfx_user_code_Transform-0.0+ada18bfeef376af7db2592bb8e75cc8d9bffe7a95b02a9bb8e811ddd10f8d83c-py3-none-any.whl'; target user module is 'transform'.
# INFO:absl:Full user module path is 'transform@C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\_wheels\\tfx_user_code_Transform-0.0+ada18bfeef376af7db2592bb8e75cc8d9bffe7a95b02a9bb8e811ddd10f8d83c-py3-none-any.whl'
# INFO:absl:Generating ephemeral wheel package for 'C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\modules\\trainer.py' (including modules: ['components', 'trainer', 'transform']).
# INFO:absl:User module package has hash fingerprint version ada18bfeef376af7db2592bb8e75cc8d9bffe7a95b02a9bb8e811ddd10f8d83c.
# INFO:absl:Executing: ['C:\\Users\\Dragon\\AppData\\Local\\Programs\\Python\\Python39\\python.exe', 'C:\\Users\\Dragon\\AppData\\Local\\Temp\\tmptt47r5ec\\_tfx_generated_setup.py', 'bdist_wheel', '--bdist-dir', 'C:\\Users\\Dragon\\AppData\\Local\\Temp\\tmpyskhpdxu', '--dist-dir', 'C:\\Users\\Dragon\\AppData\\Local\\Temp\\tmpqu31a8t1']
# INFO:absl:Successfully built user code wheel distribution at 'C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\_wheels\\tfx_user_code_Trainer-0.0+ada18bfeef376af7db2592bb8e75cc8d9bffe7a95b02a9bb8e811ddd10f8d83c-py3-none-any.whl'; target user module is 'trainer'.
# INFO:absl:Full user module path is 'trainer@C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\_wheels\\tfx_user_code_Trainer-0.0+ada18bfeef376af7db2592bb8e75cc8d9bffe7a95b02a9bb8e811ddd10f8d83c-py3-none-any.whl'
# INFO:absl:Using deployment config:
#  executor_specs {
#   key: "CsvExampleGen"
#   value {
#     beam_executable_spec {
#       python_executor_spec {
#         class_path: "tfx.components.example_gen.csv_example_gen.executor.Executor"
#       }
#     }
#   }
# }
# executor_specs {
#   key: "Evaluator"
#   value {
#     beam_executable_spec {
#       python_executor_spec {
#         class_path: "tfx.components.evaluator.executor.Executor"
#       }
#     }
#   }
# }
# executor_specs {
#   key: "ExampleValidator"
#   value {
#     python_class_executable_spec {
#       class_path: "tfx.components.example_validator.executor.Executor"
#     }
#   }
# }
# executor_specs {
#   key: "Pusher"
#   value {
#     python_class_executable_spec {
#       class_path: "tfx.components.pusher.executor.Executor"
#     }
#   }
# }
# executor_specs {
#   key: "SchemaGen"
#   value {
#     python_class_executable_spec {
#       class_path: "tfx.components.schema_gen.executor.Executor"
#     }
#   }
# }
# executor_specs {
#   key: "StatisticsGen"
#   value {
#     beam_executable_spec {
#       python_executor_spec {
#         class_path: "tfx.components.statistics_gen.executor.Executor"
#       }
#     }
#   }
# }
# executor_specs {
#   key: "Trainer"
#   value {
#     python_class_executable_spec {
#       class_path: "tfx.components.trainer.executor.GenericExecutor"
#     }
#   }
# }
# executor_specs {
#   key: "Transform"
#   value {
#     beam_executable_spec {
#       python_executor_spec {
#         class_path: "tfx.components.transform.executor.Executor"
#       }
#     }
#   }
# }
# custom_driver_specs {
#   key: "CsvExampleGen"
#   value {
#     python_class_executable_spec {
#       class_path: "tfx.components.example_gen.driver.FileBasedDriver"
#     }
#   }
# }
# metadata_connection_config {
#   database_connection_config {
#     sqlite {
#       filename_uri: "C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\metadata\\metadata.db"
#       connection_mode: READWRITE_OPENCREATE
#     }
#   }
# }
#
# INFO:absl:Using connection config:
#  sqlite {
#   filename_uri: "C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\metadata\\metadata.db"
#   connection_mode: READWRITE_OPENCREATE
# }
#
# INFO:root:Missing pipeline option (runner). Executing pipeline using the default runner: DirectRunner.
# WARNING:apache_beam.runners.interactive.interactive_environment:Dependencies required for Interactive Beam PCollection visualization are not available, please use: `pip install apache-beam[interactive]` to install necessary dependencies to enable all data visualization features.
# INFO:absl:Node CsvExampleGen depends on [].
# INFO:absl:Node CsvExampleGen is scheduled.
# INFO:absl:Node Latest_blessed_model_resolver depends on [].
# INFO:absl:Node Latest_blessed_model_resolver is scheduled.
# INFO:absl:Node StatisticsGen depends on ['Run[CsvExampleGen]'].
# INFO:absl:Node StatisticsGen is scheduled.
# INFO:absl:Node SchemaGen depends on ['Run[StatisticsGen]'].
# INFO:absl:Node SchemaGen is scheduled.
# INFO:absl:Node ExampleValidator depends on ['Run[SchemaGen]', 'Run[StatisticsGen]'].
# INFO:absl:Node ExampleValidator is scheduled.
# INFO:absl:Node Transform depends on ['Run[CsvExampleGen]', 'Run[SchemaGen]'].
# INFO:absl:Node Transform is scheduled.
# INFO:absl:Node Trainer depends on ['Run[SchemaGen]', 'Run[Transform]'].
# INFO:absl:Node Trainer is scheduled.
# INFO:absl:Node Evaluator depends on ['Run[CsvExampleGen]', 'Run[Latest_blessed_model_resolver]', 'Run[Trainer]'].
# INFO:absl:Node Evaluator is scheduled.
# INFO:absl:Node Pusher depends on ['Run[Evaluator]', 'Run[Trainer]'].
# INFO:absl:Node Pusher is scheduled.
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.44.0
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function annotate_downstream_side_inputs at 0x0000026FA2D09040> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function fix_side_input_pcoll_coders at 0x0000026FA2D09160> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function pack_combiners at 0x0000026FA2D09670> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function lift_combiners at 0x0000026FA2D09700> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function expand_sdf at 0x0000026FA2D098B0> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function expand_gbk at 0x0000026FA2D09940> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function sink_flattens at 0x0000026FA2D09A60> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function greedily_fuse at 0x0000026FA2D09AF0> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function read_to_impulse at 0x0000026FA2D09B80> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function impulse_to_input at 0x0000026FA2D09C10> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function sort_stages at 0x0000026FA2D09E50> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function add_impulse_to_dangling_transforms at 0x0000026FA2D09F70> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function setup_timer_mapping at 0x0000026FA2D09DC0> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function populate_data_channel_coders at 0x0000026FA2D09EE0> ====================
# INFO:apache_beam.runners.worker.statecache:Creating state cache with size 104857600
# INFO:apache_beam.runners.portability.fn_api_runner.worker_handlers:Created Worker handler <apache_beam.runners.portability.fn_api_runner.worker_handlers.EmbeddedWorkerHandler object at 0x0000026FA6B98AF0> for environment ref_Environment_default_environment_1 (beam:env:embedded_python:v1, b'')
# INFO:absl:node Latest_blessed_model_resolver is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.dsl.components.common.resolver.Resolver"
#   }
#   id: "Latest_blessed_model_resolver"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "andyid_pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20260708-210150.129722"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "andyid_pipeline.Latest_blessed_model_resolver"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "_generated_model_3"
#     value {
#       channels {
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "andyid_pipeline"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#       }
#       hidden: true
#     }
#   }
#   inputs {
#     key: "_generated_modelblessing_4"
#     value {
#       channels {
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "andyid_pipeline"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "ModelBlessing"
#           }
#         }
#       }
#       hidden: true
#     }
#   }
#   inputs {
#     key: "model"
#     value {
#       input_graph_ref {
#         graph_id: "graph_1"
#         key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "model_blessing"
#     value {
#       input_graph_ref {
#         graph_id: "graph_1"
#         key: "model_blessing"
#       }
#     }
#   }
#   input_graphs {
#     key: "graph_1"
#     value {
#       nodes {
#         key: "dict_2"
#         value {
#           output_data_type: ARTIFACT_MULTIMAP
#           dict_node {
#             node_ids {
#               key: "model"
#               value: "input_3"
#             }
#             node_ids {
#               key: "model_blessing"
#               value: "input_4"
#             }
#           }
#         }
#       }
#       nodes {
#         key: "input_3"
#         value {
#           output_data_type: ARTIFACT_LIST
#           input_node {
#             input_key: "_generated_model_3"
#           }
#         }
#       }
#       nodes {
#         key: "input_4"
#         value {
#           output_data_type: ARTIFACT_LIST
#           input_node {
#             input_key: "_generated_modelblessing_4"
#           }
#         }
#       }
#       nodes {
#         key: "op_1"
#         value {
#           output_data_type: ARTIFACT_MULTIMAP
#           op_node {
#             op_type: "tfx.dsl.input_resolution.strategies.latest_blessed_model_strategy.LatestBlessedModelStrategy"
#             args {
#               node_id: "dict_2"
#             }
#           }
#         }
#       }
#       result_node: "op_1"
#     }
#   }
# }
# downstream_nodes: "Evaluator"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:Running as an resolver node.
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:[Latest_blessed_model_resolver] Resolved inputs: ({'model': [], 'model_blessing': []},)
# INFO:absl:node Latest_blessed_model_resolver is finished.
# INFO:absl:node CsvExampleGen is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.example_gen.csv_example_gen.component.CsvExampleGen"
#   }
#   id: "CsvExampleGen"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "andyid_pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20260708-210150.129722"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "andyid_pipeline.CsvExampleGen"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "examples"
#     value {
#       artifact_spec {
#         type {
#           name: "Examples"
#           properties {
#             key: "span"
#             value: INT
#           }
#           properties {
#             key: "split_names"
#             value: STRING
#           }
#           properties {
#             key: "version"
#             value: INT
#           }
#           base_type: DATASET
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "input_base"
#     value {
#       field_value {
#         string_value: "data"
#       }
#     }
#   }
#   parameters {
#     key: "input_config"
#     value {
#       field_value {
#         string_value: "{\n  \"splits\": [\n    {\n      \"name\": \"single_split\",\n      \"pattern\": \"*\"\n    }\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "output_config"
#     value {
#       field_value {
#         string_value: "{\n  \"split_config\": {\n    \"splits\": [\n      {\n        \"hash_buckets\": 8,\n        \"name\": \"train\"\n      },\n      {\n        \"hash_buckets\": 2,\n        \"name\": \"eval\"\n      }\n    ]\n  }\n}"
#       }
#     }
#   }
#   parameters {
#     key: "output_data_format"
#     value {
#       field_value {
#         int_value: 6
#       }
#     }
#   }
#   parameters {
#     key: "output_file_format"
#     value {
#       field_value {
#         int_value: 5
#       }
#     }
#   }
# }
# downstream_nodes: "Evaluator"
# downstream_nodes: "StatisticsGen"
# downstream_nodes: "Transform"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:[CsvExampleGen] Resolved inputs: ({},)
# INFO:absl:select span and version = (0, None)
# INFO:absl:latest span and version = (0, None)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:A cached execution 8 is used.
# INFO:absl:node CsvExampleGen is finished.
# INFO:absl:node StatisticsGen is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.statistics_gen.component.StatisticsGen"
#     base_type: PROCESS
#   }
#   id: "StatisticsGen"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "andyid_pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20260708-210150.129722"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "andyid_pipeline.StatisticsGen"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "CsvExampleGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "andyid_pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20260708-210150.129722"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "andyid_pipeline.CsvExampleGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "examples"
#       }
#       min_count: 1
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "statistics"
#     value {
#       artifact_spec {
#         type {
#           name: "ExampleStatistics"
#           properties {
#             key: "span"
#             value: INT
#           }
#           properties {
#             key: "split_names"
#             value: STRING
#           }
#           base_type: STATISTICS
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "exclude_splits"
#     value {
#       field_value {
#         string_value: "[]"
#       }
#     }
#   }
# }
# upstream_nodes: "CsvExampleGen"
# downstream_nodes: "ExampleValidator"
# downstream_nodes: "SchemaGen"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[StatisticsGen] Resolved inputs: ({'examples': [Artifact(artifact: id: 1
# type_id: 16
# uri: "C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\CsvExampleGen\\examples\\2"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "file_format"
#   value {
#     string_value: "tfrecords_gzip"
#   }
# }
# custom_properties {
#   key: "input_fingerprint"
#   value {
#     string_value: "split:single_split,num_files:1,total_bytes:442038,xor_checksum:1783481272,sum_checksum:1783481272"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "payload_format"
#   value {
#     string_value: "FORMAT_TF_EXAMPLE"
#   }
# }
# custom_properties {
#   key: "span"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1783518619801
# last_update_time_since_epoch: 1783518619801
# , artifact_type: id: 16
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:A cached execution 9 is used.
# INFO:absl:node StatisticsGen is finished.
# INFO:absl:node SchemaGen is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.schema_gen.component.SchemaGen"
#     base_type: PROCESS
#   }
#   id: "SchemaGen"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "andyid_pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20260708-210150.129722"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "andyid_pipeline.SchemaGen"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "statistics"
#     value {
#       channels {
#         producer_node_query {
#           id: "StatisticsGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "andyid_pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20260708-210150.129722"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "andyid_pipeline.StatisticsGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "ExampleStatistics"
#             base_type: STATISTICS
#           }
#         }
#         output_key: "statistics"
#       }
#       min_count: 1
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "schema"
#     value {
#       artifact_spec {
#         type {
#           name: "Schema"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "exclude_splits"
#     value {
#       field_value {
#         string_value: "[]"
#       }
#     }
#   }
#   parameters {
#     key: "infer_feature_shape"
#     value {
#       field_value {
#         int_value: 1
#       }
#     }
#   }
# }
# upstream_nodes: "StatisticsGen"
# downstream_nodes: "ExampleValidator"
# downstream_nodes: "Trainer"
# downstream_nodes: "Transform"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[SchemaGen] Resolved inputs: ({'statistics': [Artifact(artifact: id: 2
# type_id: 18
# uri: "C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\StatisticsGen\\statistics\\3"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1783518632472
# last_update_time_since_epoch: 1783518632472
# , artifact_type: id: 18
# name: "ExampleStatistics"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# base_type: STATISTICS
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:A cached execution 10 is used.
# INFO:absl:node SchemaGen is finished.
# INFO:absl:node ExampleValidator is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.example_validator.component.ExampleValidator"
#   }
#   id: "ExampleValidator"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "andyid_pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20260708-210150.129722"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "andyid_pipeline.ExampleValidator"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "schema"
#     value {
#       channels {
#         producer_node_query {
#           id: "SchemaGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "andyid_pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20260708-210150.129722"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "andyid_pipeline.SchemaGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Schema"
#           }
#         }
#         output_key: "schema"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "statistics"
#     value {
#       channels {
#         producer_node_query {
#           id: "StatisticsGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "andyid_pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20260708-210150.129722"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "andyid_pipeline.StatisticsGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "ExampleStatistics"
#             base_type: STATISTICS
#           }
#         }
#         output_key: "statistics"
#       }
#       min_count: 1
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "anomalies"
#     value {
#       artifact_spec {
#         type {
#           name: "ExampleAnomalies"
#           properties {
#             key: "span"
#             value: INT
#           }
#           properties {
#             key: "split_names"
#             value: STRING
#           }
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "exclude_splits"
#     value {
#       field_value {
#         string_value: "[]"
#       }
#     }
#   }
# }
# upstream_nodes: "SchemaGen"
# upstream_nodes: "StatisticsGen"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[ExampleValidator] Resolved inputs: ({'schema': [Artifact(artifact: id: 3
# type_id: 20
# uri: "C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\SchemaGen\\schema\\4"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1783518633018
# last_update_time_since_epoch: 1783518633018
# , artifact_type: id: 20
# name: "Schema"
# )], 'statistics': [Artifact(artifact: id: 2
# type_id: 18
# uri: "C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\StatisticsGen\\statistics\\3"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1783518632472
# last_update_time_since_epoch: 1783518632472
# , artifact_type: id: 18
# name: "ExampleStatistics"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# base_type: STATISTICS
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:A cached execution 11 is used.
# INFO:absl:node ExampleValidator is finished.
# INFO:absl:node Transform is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.transform.component.Transform"
#     base_type: TRANSFORM
#   }
#   id: "Transform"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "andyid_pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20260708-210150.129722"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "andyid_pipeline.Transform"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "CsvExampleGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "andyid_pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20260708-210150.129722"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "andyid_pipeline.CsvExampleGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "schema"
#     value {
#       channels {
#         producer_node_query {
#           id: "SchemaGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "andyid_pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20260708-210150.129722"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "andyid_pipeline.SchemaGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Schema"
#           }
#         }
#         output_key: "schema"
#       }
#       min_count: 1
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "post_transform_anomalies"
#     value {
#       artifact_spec {
#         type {
#           name: "ExampleAnomalies"
#           properties {
#             key: "span"
#             value: INT
#           }
#           properties {
#             key: "split_names"
#             value: STRING
#           }
#         }
#       }
#     }
#   }
#   outputs {
#     key: "post_transform_schema"
#     value {
#       artifact_spec {
#         type {
#           name: "Schema"
#         }
#       }
#     }
#   }
#   outputs {
#     key: "post_transform_stats"
#     value {
#       artifact_spec {
#         type {
#           name: "ExampleStatistics"
#           properties {
#             key: "span"
#             value: INT
#           }
#           properties {
#             key: "split_names"
#             value: STRING
#           }
#           base_type: STATISTICS
#         }
#       }
#     }
#   }
#   outputs {
#     key: "pre_transform_schema"
#     value {
#       artifact_spec {
#         type {
#           name: "Schema"
#         }
#       }
#     }
#   }
#   outputs {
#     key: "pre_transform_stats"
#     value {
#       artifact_spec {
#         type {
#           name: "ExampleStatistics"
#           properties {
#             key: "span"
#             value: INT
#           }
#           properties {
#             key: "split_names"
#             value: STRING
#           }
#           base_type: STATISTICS
#         }
#       }
#     }
#   }
#   outputs {
#     key: "transform_graph"
#     value {
#       artifact_spec {
#         type {
#           name: "TransformGraph"
#         }
#       }
#     }
#   }
#   outputs {
#     key: "transformed_examples"
#     value {
#       artifact_spec {
#         type {
#           name: "Examples"
#           properties {
#             key: "span"
#             value: INT
#           }
#           properties {
#             key: "split_names"
#             value: STRING
#           }
#           properties {
#             key: "version"
#             value: INT
#           }
#           base_type: DATASET
#         }
#       }
#     }
#   }
#   outputs {
#     key: "updated_analyzer_cache"
#     value {
#       artifact_spec {
#         type {
#           name: "TransformCache"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "disable_statistics"
#     value {
#       field_value {
#         int_value: 0
#       }
#     }
#   }
#   parameters {
#     key: "force_tf_compat_v1"
#     value {
#       field_value {
#         int_value: 0
#       }
#     }
#   }
#   parameters {
#     key: "module_path"
#     value {
#       field_value {
#         string_value: "transform@C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\_wheels\\tfx_user_code_Transform-0.0+ada18bfeef376af7db2592bb8e75cc8d9bffe7a95b02a9bb8e811ddd10f8d83c-py3-none-any.whl"
#       }
#     }
#   }
# }
# upstream_nodes: "CsvExampleGen"
# upstream_nodes: "SchemaGen"
# downstream_nodes: "Trainer"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[Transform] Resolved inputs: ({'schema': [Artifact(artifact: id: 3
# type_id: 20
# uri: "C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\SchemaGen\\schema\\4"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1783518633018
# last_update_time_since_epoch: 1783518633018
# , artifact_type: id: 20
# name: "Schema"
# )], 'examples': [Artifact(artifact: id: 1
# type_id: 16
# uri: "C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\CsvExampleGen\\examples\\2"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "file_format"
#   value {
#     string_value: "tfrecords_gzip"
#   }
# }
# custom_properties {
#   key: "input_fingerprint"
#   value {
#     string_value: "split:single_split,num_files:1,total_bytes:442038,xor_checksum:1783481272,sum_checksum:1783481272"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "payload_format"
#   value {
#     string_value: "FORMAT_TF_EXAMPLE"
#   }
# }
# custom_properties {
#   key: "span"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1783518619801
# last_update_time_since_epoch: 1783518619801
# , artifact_type: id: 16
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Going to run a new execution 12
# INFO:absl:Going to run a new execution: ExecutionInfo(execution_id=12, input_dict={'schema': [Artifact(artifact: id: 3
# type_id: 20
# uri: "C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\SchemaGen\\schema\\4"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1783518633018
# last_update_time_since_epoch: 1783518633018
# , artifact_type: id: 20
# name: "Schema"
# )], 'examples': [Artifact(artifact: id: 1
# type_id: 16
# uri: "C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\CsvExampleGen\\examples\\2"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "file_format"
#   value {
#     string_value: "tfrecords_gzip"
#   }
# }
# custom_properties {
#   key: "input_fingerprint"
#   value {
#     string_value: "split:single_split,num_files:1,total_bytes:442038,xor_checksum:1783481272,sum_checksum:1783481272"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "payload_format"
#   value {
#     string_value: "FORMAT_TF_EXAMPLE"
#   }
# }
# custom_properties {
#   key: "span"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1783518619801
# last_update_time_since_epoch: 1783518619801
# , artifact_type: id: 16
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )]}, output_dict=defaultdict(<class 'list'>, {'post_transform_schema': [Artifact(artifact: uri: "C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\Transform\\post_transform_schema\\12"
# , artifact_type: name: "Schema"
# )], 'pre_transform_schema': [Artifact(artifact: uri: "C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\Transform\\pre_transform_schema\\12"
# , artifact_type: name: "Schema"
# )], 'post_transform_anomalies': [Artifact(artifact: uri: "C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\Transform\\post_transform_anomalies\\12"
# , artifact_type: name: "ExampleAnomalies"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# )], 'post_transform_stats': [Artifact(artifact: uri: "C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\Transform\\post_transform_stats\\12"
# , artifact_type: name: "ExampleStatistics"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# base_type: STATISTICS
# )], 'updated_analyzer_cache': [Artifact(artifact: uri: "C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\Transform\\updated_analyzer_cache\\12"
# , artifact_type: name: "TransformCache"
# )], 'transformed_examples': [Artifact(artifact: uri: "C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\Transform\\transformed_examples\\12"
# , artifact_type: name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )], 'pre_transform_stats': [Artifact(artifact: uri: "C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\Transform\\pre_transform_stats\\12"
# , artifact_type: name: "ExampleStatistics"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# base_type: STATISTICS
# )], 'transform_graph': [Artifact(artifact: uri: "C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\Transform\\transform_graph\\12"
# , artifact_type: name: "TransformGraph"
# )]}), exec_properties={'custom_config': 'null', 'disable_statistics': 0, 'module_path': 'transform@C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\_wheels\\tfx_user_code_Transform-0.0+ada18bfeef376af7db2592bb8e75cc8d9bffe7a95b02a9bb8e811ddd10f8d83c-py3-none-any.whl', 'force_tf_compat_v1': 0}, execution_output_uri='C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\Transform\\.system\\executor_execution\\12\\executor_output.pb', stateful_working_dir='C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\Transform\\.system\\stateful_working_dir\\20260708-210150.129722', tmp_dir='C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\Transform\\.system\\executor_execution\\12\\.temp\\', pipeline_node=node_info {
#   type {
#     name: "tfx.components.transform.component.Transform"
#     base_type: TRANSFORM
#   }
#   id: "Transform"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "andyid_pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20260708-210150.129722"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "andyid_pipeline.Transform"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "CsvExampleGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "andyid_pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20260708-210150.129722"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "andyid_pipeline.CsvExampleGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "schema"
#     value {
#       channels {
#         producer_node_query {
#           id: "SchemaGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "andyid_pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20260708-210150.129722"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "andyid_pipeline.SchemaGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Schema"
#           }
#         }
#         output_key: "schema"
#       }
#       min_count: 1
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "post_transform_anomalies"
#     value {
#       artifact_spec {
#         type {
#           name: "ExampleAnomalies"
#           properties {
#             key: "span"
#             value: INT
#           }
#           properties {
#             key: "split_names"
#             value: STRING
#           }
#         }
#       }
#     }
#   }
#   outputs {
#     key: "post_transform_schema"
#     value {
#       artifact_spec {
#         type {
#           name: "Schema"
#         }
#       }
#     }
#   }
#   outputs {
#     key: "post_transform_stats"
#     value {
#       artifact_spec {
#         type {
#           name: "ExampleStatistics"
#           properties {
#             key: "span"
#             value: INT
#           }
#           properties {
#             key: "split_names"
#             value: STRING
#           }
#           base_type: STATISTICS
#         }
#       }
#     }
#   }
#   outputs {
#     key: "pre_transform_schema"
#     value {
#       artifact_spec {
#         type {
#           name: "Schema"
#         }
#       }
#     }
#   }
#   outputs {
#     key: "pre_transform_stats"
#     value {
#       artifact_spec {
#         type {
#           name: "ExampleStatistics"
#           properties {
#             key: "span"
#             value: INT
#           }
#           properties {
#             key: "split_names"
#             value: STRING
#           }
#           base_type: STATISTICS
#         }
#       }
#     }
#   }
#   outputs {
#     key: "transform_graph"
#     value {
#       artifact_spec {
#         type {
#           name: "TransformGraph"
#         }
#       }
#     }
#   }
#   outputs {
#     key: "transformed_examples"
#     value {
#       artifact_spec {
#         type {
#           name: "Examples"
#           properties {
#             key: "span"
#             value: INT
#           }
#           properties {
#             key: "split_names"
#             value: STRING
#           }
#           properties {
#             key: "version"
#             value: INT
#           }
#           base_type: DATASET
#         }
#       }
#     }
#   }
#   outputs {
#     key: "updated_analyzer_cache"
#     value {
#       artifact_spec {
#         type {
#           name: "TransformCache"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "disable_statistics"
#     value {
#       field_value {
#         int_value: 0
#       }
#     }
#   }
#   parameters {
#     key: "force_tf_compat_v1"
#     value {
#       field_value {
#         int_value: 0
#       }
#     }
#   }
#   parameters {
#     key: "module_path"
#     value {
#       field_value {
#         string_value: "transform@C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\_wheels\\tfx_user_code_Transform-0.0+ada18bfeef376af7db2592bb8e75cc8d9bffe7a95b02a9bb8e811ddd10f8d83c-py3-none-any.whl"
#       }
#     }
#   }
# }
# upstream_nodes: "CsvExampleGen"
# upstream_nodes: "SchemaGen"
# downstream_nodes: "Trainer"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# , pipeline_info=id: "andyid_pipeline"
# , pipeline_run_id='20260708-210150.129722')
# INFO:absl:Analyze the 'train' split and transform all splits when splits_config is not set.
# INFO:absl:udf_utils.get_fn {'module_file': None, 'module_path': 'transform@C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\_wheels\\tfx_user_code_Transform-0.0+ada18bfeef376af7db2592bb8e75cc8d9bffe7a95b02a9bb8e811ddd10f8d83c-py3-none-any.whl', 'preprocessing_fn': None} 'preprocessing_fn'
# INFO:absl:Installing 'C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\_wheels\\tfx_user_code_Transform-0.0+ada18bfeef376af7db2592bb8e75cc8d9bffe7a95b02a9bb8e811ddd10f8d83c-py3-none-any.whl' to a temporary directory.
# INFO:absl:Executing: ['C:\\Users\\Dragon\\AppData\\Local\\Programs\\Python\\Python39\\python.exe', '-m', 'pip', 'install', '--target', 'C:\\Users\\Dragon\\AppData\\Local\\Temp\\tmplmq8wxb5', 'C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\_wheels\\tfx_user_code_Transform-0.0+ada18bfeef376af7db2592bb8e75cc8d9bffe7a95b02a9bb8e811ddd10f8d83c-py3-none-any.whl']
# INFO:absl:Successfully installed 'C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\_wheels\\tfx_user_code_Transform-0.0+ada18bfeef376af7db2592bb8e75cc8d9bffe7a95b02a9bb8e811ddd10f8d83c-py3-none-any.whl'.
# INFO:absl:udf_utils.get_fn {'module_file': None, 'module_path': 'transform@C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\_wheels\\tfx_user_code_Transform-0.0+ada18bfeef376af7db2592bb8e75cc8d9bffe7a95b02a9bb8e811ddd10f8d83c-py3-none-any.whl', 'stats_options_updater_fn': None} 'stats_options_updater_fn'
# INFO:absl:Installing 'C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\_wheels\\tfx_user_code_Transform-0.0+ada18bfeef376af7db2592bb8e75cc8d9bffe7a95b02a9bb8e811ddd10f8d83c-py3-none-any.whl' to a temporary directory.
# INFO:absl:Executing: ['C:\\Users\\Dragon\\AppData\\Local\\Programs\\Python\\Python39\\python.exe', '-m', 'pip', 'install', '--target', 'C:\\Users\\Dragon\\AppData\\Local\\Temp\\tmpz_ryq_z6', 'C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\_wheels\\tfx_user_code_Transform-0.0+ada18bfeef376af7db2592bb8e75cc8d9bffe7a95b02a9bb8e811ddd10f8d83c-py3-none-any.whl']
# INFO:absl:Successfully installed 'C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\_wheels\\tfx_user_code_Transform-0.0+ada18bfeef376af7db2592bb8e75cc8d9bffe7a95b02a9bb8e811ddd10f8d83c-py3-none-any.whl'.
# INFO:absl:Installing 'C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\_wheels\\tfx_user_code_Transform-0.0+ada18bfeef376af7db2592bb8e75cc8d9bffe7a95b02a9bb8e811ddd10f8d83c-py3-none-any.whl' to a temporary directory.
# INFO:absl:Executing: ['C:\\Users\\Dragon\\AppData\\Local\\Programs\\Python\\Python39\\python.exe', '-m', 'pip', 'install', '--target', 'C:\\Users\\Dragon\\AppData\\Local\\Temp\\tmpxg9spjkl', 'C:\\Users\\Dragon\\Documents\\github\\andyid23\\mlops\\deploy-ops\\andyid_pipeline\\_wheels\\tfx_user_code_Transform-0.0+ada18bfeef376af7db2592bb8e75cc8d9bffe7a95b02a9bb8e811ddd10f8d83c-py3-none-any.whl']
# ...
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.PerWindowInvoker._invoke_process_per_window()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py in process(self, element, *signals)
#      89     logging.info('node %s is running.', self._node_id)
# ---> 90     self._run_node()
#      91     logging.info('node %s is finished.', self._node_id)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py in _run_node(self)
#      98         partial_run_utils.snapshot(mlmd_handle, self._pipeline)
# ---> 99     launcher.Launcher(
#     100         pipeline_node=self._pipeline_node,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tfx\orchestration\portable\launcher.py in launch(self)
#     572           executor_watcher.start()
# --> 573         executor_output = self._run_executor(execution_info)
#     574       except Exception as e:  # pylint: disable=broad-except
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tfx\orchestration\portable\launcher.py in _run_executor(self, execution_info)
#     447     try:
# --> 448       executor_output = self._executor_operator.run_executor(execution_info)
#     449       code = executor_output.execution_result.code
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tfx\orchestration\portable\python_executor_operator.py in run_executor(self, execution_info)
#     134     executor = self._executor_cls(context=context)
# --> 135     return run_with_executor(execution_info, executor)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tfx\orchestration\portable\python_executor_operator.py in run_with_executor(execution_info, executor)
#      57   output_dict = copy.deepcopy(execution_info.output_dict)
# ---> 58   result = executor.Do(execution_info.input_dict, output_dict,
#      59                        execution_info.exec_properties)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tfx\components\trainer\executor.py in Do(self, input_dict, output_dict, exec_properties)
#     177     absl.logging.info('Training model.')
# --> 178     run_fn(fn_args)
#     179
#
# ~\AppData\Local\Temp\tmpqx4u4ylk\trainer.py in run_fn(fn_args)
#     156
# --> 157     model.fit(
#     158         train_dataset,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\engine\data_adapter.py in _validate_args(self, y, sample_weights, steps)
#     819             ):
# --> 820                 raise ValueError(
#     821                     "When providing an infinite dataset, you must specify "
#
# ValueError: When providing an infinite dataset, you must specify the number of steps to run (if you did not intend to create an infinite dataset, make sure to not call `repeat()` on the dataset).
#
# During handling of the above exception, another exception occurred:
#
# ValueError                            Traceback (most recent call last)
# ~\Documents\github\andyid23\mlops\deploy-ops\andyid-pipeline\local_pipeline.py in <module>
#     166 # Jalankan pipeline jika file ini dieksekusi langsung
#     167 if __name__ == '__main__':
# --> 168     init_pipeline(PIPELINE_NAME, PIPELINE_ROOT, METADATA_PATH)
#
# ~\Documents\github\andyid23\mlops\deploy-ops\andyid-pipeline\local_pipeline.py in init_pipeline(pipeline_name, pipeline_root, metadata_path)
#     161
#     162     print(f"Menjalankan pipeline: {pipeline_name}")
# --> 163     BeamDagRunner().run(pipeline_config)
#     164
#     165
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tfx\orchestration\portable\tfx_runner.py in run(self, pipeline, run_options, **kwargs)
#     122     else:
#     123       run_options_pb = None
# --> 124     return self.run_with_ir(pipeline_pb, run_options=run_options_pb, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py in run_with_ir(self, pipeline, run_options)
#     295                       pipeline=pipeline),
#     296                   *[beam.pvalue.AsIter(s) for s in signals_to_wait]))
# --> 297           logging.info('Node %s is scheduled.', node_id)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\pipeline.py in __exit__(self, exc_type, exc_val, exc_tb)
#     598     try:
#     599       if not exc_type:
# --> 600         self.result = self.run()
#     601         self.result.wait_until_finish()
#     602     finally:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\pipeline.py in run(self, test_runner_api)
#     575         finally:
#     576           shutil.rmtree(tmpdir)
# --> 577       return self.runner.run_pipeline(self, self._options)
#     578     finally:
#     579       if not is_in_ipython():
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\runners\direct\direct_runner.py in run_pipeline(self, pipeline, options)
#     129       runner = BundleBasedDirectRunner()
#     130
# --> 131     return runner.run_pipeline(pipeline, options)
#     132
#     133
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in run_pipeline(self, pipeline, options)
#     199         options.view_as(pipeline_options.ProfilingOptions))
#     200
# --> 201     self._latest_run_result = self.run_via_runner_api(
#     202         pipeline.to_runner_api(default_environment=self._default_environment),
#     203         options)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in run_via_runner_api(self, pipeline_proto, options)
#     220       pipeline_proto = self.embed_default_docker_image(pipeline_proto)
#     221     stage_context, stages = self.create_stages(pipeline_proto)
# --> 222     return self.run_stages(stage_context, stages)
#     223
#     224   def embed_default_docker_image(self, pipeline_proto):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in run_stages(self, stage_context, stages)
#     451
#     452           bundle_counter += 1
# --> 453           bundle_results = self._execute_bundle(
#     454               runner_execution_context, bundle_context_manager, bundle_input)
#     455
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in _execute_bundle(self, runner_execution_context, bundle_context_manager, bundle_input)
#     779
#     780     last_result, deferred_inputs, newly_set_timers, watermark_updates = (
# --> 781         self._run_bundle(
#     782             runner_execution_context,
#     783             bundle_context_manager,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in _run_bundle(self, runner_execution_context, bundle_context_manager, bundle_input, data_output, expected_timer_output, bundle_manager)
#    1008         expected_timer_output)
#    1009
# -> 1010     result, splits = bundle_manager.process_bundle(
#    1011         data_input, data_output, input_timers, expected_timer_output)
#    1012     # Now we collect all the deferred inputs remaining from bundle execution.
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in process_bundle(self, inputs, expected_outputs, fired_timers, expected_output_timers, dry_run)
#    1344             process_bundle_descriptor.id,
#    1345             cache_tokens=[next(self._cache_token_generator)]))
# -> 1346     result_future = self._worker_handler.control_conn.push(process_bundle_req)
#    1347
#    1348     split_results = []  # type: List[beam_fn_api_pb2.ProcessBundleSplitResponse]
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\runners\portability\fn_api_runner\worker_handlers.py in push(self, request)
#     377       self._uid_counter += 1
#     378       request.instruction_id = 'control_%s' % self._uid_counter
# --> 379     response = self.worker.do_instruction(request)
#     380     return ControlFuture(request.instruction_id, response)
#     381
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\runners\worker\sdk_worker.py in do_instruction(self, request)
#     594     if request_type:
#     595       # E.g. if register is set, this will call self.register(request.register))
# --> 596       return getattr(self, request_type)(
#     597           getattr(request, request_type), request.instruction_id)
#     598     else:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\runners\worker\sdk_worker.py in process_bundle(self, request, instruction_id)
#     632         with self.maybe_profile(instruction_id):
#     633           delayed_applications, requests_finalization = (
# --> 634               bundle_processor.process_bundle(instruction_id))
#     635           monitoring_infos = bundle_processor.monitoring_infos()
#     636           response = beam_fn_api_pb2.InstructionResponse(
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\runners\worker\bundle_processor.py in process_bundle(self, instruction_id)
#    1001                   element.timer_family_id, timer_data)
#    1002           elif isinstance(element, beam_fn_api_pb2.Elements.Data):
# -> 1003             input_op_by_transform_id[element.transform_id].process_encoded(
#    1004                 element.data)
#    1005
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\runners\worker\bundle_processor.py in process_encoded(self, encoded_windowed_values)
#     225       decoded_value = self.windowed_coder_impl.decode_from_stream(
#     226           input_stream, True)
# --> 227       self.output(decoded_value)
#     228
#     229   def monitoring_infos(self, transform_id, tag_to_pcollection_id):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.Operation.output()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.Operation.output()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner._reraise_augmented()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.PerWindowInvoker.invoke_process()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.PerWindowInvoker._invoke_process_per_window()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py in process(self, element, *signals)
#      88
#      89     logging.info('node %s is running.', self._node_id)
# ---> 90     self._run_node()
#      91     logging.info('node %s is finished.', self._node_id)
#      92
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py in _run_node(self)
#      97       with metadata.Metadata(self._mlmd_connection_config) as mlmd_handle:
#      98         partial_run_utils.snapshot(mlmd_handle, self._pipeline)
# ---> 99     launcher.Launcher(
#     100         pipeline_node=self._pipeline_node,
#     101         mlmd_connection=metadata.Metadata(self._mlmd_connection_config),
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tfx\orchestration\portable\launcher.py in launch(self)
#     571               executor_watcher.address)
#     572           executor_watcher.start()
# --> 573         executor_output = self._run_executor(execution_info)
#     574       except Exception as e:  # pylint: disable=broad-except
#     575         execution_output = (
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tfx\orchestration\portable\launcher.py in _run_executor(self, execution_info)
#     446     outputs_utils.make_output_dirs(execution_info.output_dict)
#     447     try:
# --> 448       executor_output = self._executor_operator.run_executor(execution_info)
#     449       code = executor_output.execution_result.code
#     450       if code != 0:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tfx\orchestration\portable\python_executor_operator.py in run_executor(self, execution_info)
#     133         pipeline_run_id=execution_info.pipeline_run_id)
#     134     executor = self._executor_cls(context=context)
# --> 135     return run_with_executor(execution_info, executor)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tfx\orchestration\portable\python_executor_operator.py in run_with_executor(execution_info, executor)
#      56
#      57   output_dict = copy.deepcopy(execution_info.output_dict)
# ---> 58   result = executor.Do(execution_info.input_dict, output_dict,
#      59                        execution_info.exec_properties)
#      60   if not result:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tfx\components\trainer\executor.py in Do(self, input_dict, output_dict, exec_properties)
#     176     # Train the model
#     177     absl.logging.info('Training model.')
# --> 178     run_fn(fn_args)
#     179
#     180     # Note: If trained with multi-node distribution workers, it is the user
#
# ~\AppData\Local\Temp\tmpqx4u4ylk\trainer.py in run_fn(fn_args)
#     155     model = _build_model(inputs, tf_transform_output)
#     156
# --> 157     model.fit(
#     158         train_dataset,
#     159         epochs=EPOCHS,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\engine\data_adapter.py in _validate_args(self, y, sample_weights, steps)
#     818                 and steps is None
#     819             ):
# --> 820                 raise ValueError(
#     821                     "When providing an infinite dataset, you must specify "
#     822                     "the number of steps to run (if you did not intend to "
#
# ValueError: When providing an infinite dataset, you must specify the number of steps to run (if you did not intend to create an infinite dataset, make sure to not call `repeat()` on the dataset). [while running 'Run[Trainer]']
# ✅ Pipeline berhasil dijalankan!

# %% [markdown]
# ## 4. Metode Pengolahan Data & Arsitektur Model
#
# ### Preprocessing (Transform)
# - Normalisasi fitur numerik menggunakan `tft.scale_to_z_score()`
# - Encoding fitur kategorikal menggunakan `tft.compute_and_apply_vocabulary()`
#
# ### Arsitektur Model
# Model menggunakan arsitektur Deep Neural Network (DNN) dengan:
# - Input Layer: sesuai jumlah fitur
# - Hidden Layer 1: 128 unit, ReLU activation
# - Hidden Layer 2: 64 unit, ReLU activation
# - Dropout: 0.3 untuk mencegah overfitting
# - Output Layer: [1 unit sigmoid untuk klasifikasi / N unit softmax untuk multiclass]
#
# ### Metrik Evaluasi
# - **Primary Metric:** [Accuracy / AUC / F1-Score]
# - **Secondary Metric:** [Loss, Precision, Recall]

# %%
# Cek artifact yang dihasilkan pipeline
print("📂 Artifact Pipeline:")
for item in os.listdir(PIPELINE_ROOT):
    if os.path.isdir(os.path.join(PIPELINE_ROOT, item)):
        print(f"  ✅ {item}")
# Out:
# 📂 Artifact Pipeline:
#   ✅ CsvExampleGen
#   ✅ ExampleValidator
#   ✅ metadata
#   ✅ SchemaGen
#   ✅ StatisticsGen
#   ✅ Trainer
#   ✅ Transform
#   ✅ _wheels

# %%
from tfx.components import Evaluator
import tensorflow_model_analysis as tfma

# Path ke hasil evaluator
evaluator_output = os.path.join(PIPELINE_ROOT, 'Evaluator', 'evaluation', '0', 'eval_config.json')

# Tampilkan metrik evaluasi
print("📊 Hasil Evaluasi Model:")
print("-" * 40)
# Anda bisa load hasil evaluasi dari folder Evaluator
# atau cukup tampilkan output yang muncul saat pipeline berjalan
# Out:
# 📊 Hasil Evaluasi Model:
# ----------------------------------------

# %% [markdown]
# ## 5. Performa Model
# [Lihat output dari Evaluator di pipeline. Contoh:]
# - **Accuracy:** [X]%
# - **AUC:** [X]
# - **Loss:** [X]
#
# Model telah berhasil di-push oleh komponen Pusher dan siap untuk di-deploy.
#
# ## 6. Opsi Deployment
# - **Platform:** Railway (https://railway.app/)
# - **Alasan:** Railway menyediakan deployment berbasis Docker yang mudah digunakan dan memiliki free tier yang cukup untuk proyek ini.
# - **Model Serving:** TensorFlow Serving di dalam Docker container.
#
# ## 7. Tautan Web App
# 🔗 **URL Model Serving:** [Isi nanti setelah deploy ke Railway]
#
# ## 8. Hasil Monitoring
# Monitoring dilakukan menggunakan Prometheus untuk melacak:
# - Request latency
# - Request count
# - Error rate
#
# 📸 Screenshot monitoring dapat dilihat pada file `andyid-monitoring.png`.
